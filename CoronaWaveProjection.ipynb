# %% [markdown]
# <a href="https://colab.research.google.com/github/tanisha00999/Divinity/blob/main/CoronaWaveProjection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Corona Wave Projection

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt
from matplotlib import style



data = pd.read_csv('/content/pennsylvania-history.csv')        #DataCollection

data['date'] = pd.to_datetime(data['date'])                #DataPre-Processing
data.set_index('date',inplace = True)

plt.style.use('dark_background')
plt.plot(data['positive'])
plt.title('Daily Covid-19 Cases')
plt.xlabel('Date')
plt.ylabel('positive')
plt.show()
